# %%
pip install python-docx
# Out:
# Collecting python-docxNote: you may need to restart the kernel to use updated packages.
#
#   Using cached python-docx-0.8.11.tar.gz (5.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: lxml>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from python-docx) (4.9.1)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py): started
#   Building wheel for python-docx (setup.py): finished with status 'done'
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184519 sha256=537e4fefbd8a4cde5070579346df9d85af9a7dff1abc8114a86b6069a7f4c05a
#   Stored in directory: c:\users\aadhavan\appdata\local\pip\cache\wheels\65\e1\9b\0c38fe6cfe02a9fe31cb6b4efd90985f17354d7f77872f2def
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11

# %%
import nltk
import os
import re
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist

# Download required NLTK resources
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aadhavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aadhavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from docx import Document

# Path to the .docx file
pos_file_path = "MasterDictionary\positive-words.docx"
neg_file_path = "MasterDictionary\_negative-words.docx"

# Open the document
pos_doc = Document(pos_file_path)
neg_doc = Document(neg_file_path)

# Initialize a variable to store extracted text
positive_words = ""
negative_words = ""

# Extract text from paragraphs
for paragraph in pos_doc.paragraphs:
    positive_words += paragraph.text + "\n"
    
for paragraph in neg_doc.paragraphs:
    negative_words += paragraph.text + "\n"

# %%
# Define functions for calculations
def calculate_sentiment(text):

    # Clean text using stopwords
    stop_words = set(stopwords.words("english"))
    words = word_tokenize(text)
    cleaned_words = [word.lower() for word in words if word.lower() not in stop_words and word.isalnum()]

    # Calculate positive, negative, polarity, and subjectivity scores
    positive_score = sum(1 for word in cleaned_words if word in positive_words)
    negative_score = sum(1 for word in cleaned_words if word in negative_words)
    total_words = len(cleaned_words)
    polarity_score = (positive_score - negative_score) / (total_words + 0.000001) # to avoid diviso by zero.
    subjectivity_score = (positive_score + negative_score) / (total_words + 0.000001)
    
    return positive_score, negative_score, polarity_score, subjectivity_score 

def calculate_readability(text):
    sentences = sent_tokenize(text)
    total_words = sum(len(word_tokenize(sentence)) for sentence in sentences)
    total_sentences = len(sentences)
    average_sentence_length = total_words / total_sentences
    
    complex_word_count = sum(1 for sentence in sentences for word in word_tokenize(sentence) if syllable_count(word) > 2)
    percentage_complex_words = complex_word_count / total_words
    
    fog_index = 0.4 * (average_sentence_length + percentage_complex_words)
    
    return fog_index

def syllable_count(word):
    vowels = "aeiouAEIOU"
    syllables = 0
    prev_char_is_vowel = False
    
    for char in word:
        if char in vowels:
            if not prev_char_is_vowel:
                syllables += 1
            prev_char_is_vowel = True
        else:
            prev_char_is_vowel = False
    
    if word.endswith(("es", "ed")):
        syllables -= 1
    
    return syllables

def calculate_word_count(text):
    words = word_tokenize(text)
    cleaned_words = [word for word in words if word.isalnum()]
    return len(cleaned_words)

def calculate_average_word_length(text):
    words = word_tokenize(text)
    total_characters = sum(len(word) for word in words)
    return total_characters / len(words) 

def calculate_complex_word_percentage(text):
    words = word_tokenize(text)
    cleaned_words = [word for word in words if word.isalnum()]
    
    complex_word_count = sum(1 for word in cleaned_words if syllable_count(word) > 2)
    total_word_count = len(cleaned_words)
    
    complex_word_percentage = (complex_word_count / total_word_count) * 100
    
    return complex_word_percentage, complex_word_count

# %%
# Define folder path
folder_path = "extracted_articles"

# Loop through each text file
results = []

# %%
for text_file in os.listdir(folder_path):
    if text_file.endswith(".txt"):
        file_path = os.path.join(folder_path, text_file)
        
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()

            # Calculate sentiment analysis scores
            positive_score, negative_score, polarity_score, subjectivity_score = calculate_sentiment(text)

            # calculate syllables
            syllable_per_word =[{word:syllable_count(word)} for word in words]

            # Calculate other metrics
            fog_index = calculate_readability(text)
            word_count = calculate_word_count(text)
            average_word_length = calculate_average_word_length(text)
            complex_word_percentage, complex_word_count = calculate_complex_word_percentage(text)


            # Append results to list
            results.append({
                "File Name": text_file,
                "POSITIVE SCORE":positive_score,
                "NEGATIVE SCORE":negative_score,
                "POLARITY SCORE":polarity_score,
                "SUBJECTIVITY SCORE":subjectivity_score,
                "FOG INDEX": fog_index,
                "WORD COOUNT": word_count,
                "AVERAGE WORD PER LENGTH": average_word_length,
                "SYLLABLE PER WORD":syllable_per_word,
                "COMPLEX WORD COUNT":complex_word_count,
                "PERCENTAGE OF COMPLEX WORDS":complex_word_percentage
            })

# Display or save the results
for result in results:
    print(result)

# Optionally, save results to a CSV file
import pandas as pd

results_df = pd.DataFrame(results)
results_csv_path = "results.csv"
results_df.to_csv(results_csv_path, index=False)
# Out:
# {'File Name': '100.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.171781765010511, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.907301916105645, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.525977816695857}
# {'File Name': '101.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.052261306480139394, 'SUBJECTIVITY SCORE': 0.44221105483194867, 'FOG INDEX': 9.143602750190986, 'WORD COOUNT': 1708, 'AVERAGE WORD PER LENGTH': 4.9111688311688315, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.536299765807964}
# {'File Name': '102.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05315947838198648, 'SUBJECTIVITY SCORE': 0.44433299855132097, 'FOG INDEX': 9.06151102542475, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.907772020725389, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '103.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05315947838198648, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.085167958656331, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.910594315245478, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 406, 'PERCENTAGE OF COMPLEX WORDS': 23.65967365967366}
# {'File Name': '104.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05326633160475745, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.16732703444072, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.910880829015544, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.598130841121495}
# {'File Name': '105.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05215646935591126, 'SUBJECTIVITY SCORE': 0.4413239714730953, 'FOG INDEX': 9.071139679329772, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.913043478260869, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.598130841121495}
# {'File Name': '106.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.051051050999948895, 'SUBJECTIVITY SCORE': 0.4414414409995581, 'FOG INDEX': 9.186388466451731, 'WORD COOUNT': 1714, 'AVERAGE WORD PER LENGTH': 4.910548086866598, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 406, 'PERCENTAGE OF COMPLEX WORDS': 23.687281213535588}
# {'File Name': '107.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.052261306480139394, 'SUBJECTIVITY SCORE': 0.44221105483194867, 'FOG INDEX': 9.052504101129017, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.912863070539419, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.63955529549444}
# {'File Name': '108.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.447236180455039, 'FOG INDEX': 9.06130377153874, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.905181347150259, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.495032144944478}
# {'File Name': '109.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.05505505499994489, 'SUBJECTIVITY SCORE': 0.4434434429995561, 'FOG INDEX': 9.185974815986375, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.910031023784902, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.543123543123542}
# {'File Name': '110.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05231388324716913, 'SUBJECTIVITY SCORE': 0.44265593516835416, 'FOG INDEX': 9.056903806044826, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.909797822706065, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.58104154476302}
# {'File Name': '111.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.15800341713449, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.914419087136929, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '112.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.447236180455039, 'FOG INDEX': 9.06130377153874, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.905181347150259, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.495032144944478}
# {'File Name': '113.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.15800341713449, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.913381742738589, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.625730994152047}
# {'File Name': '114.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.171781765010511, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.907301916105645, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.525977816695857}
# {'File Name': '115.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05231388324716913, 'SUBJECTIVITY SCORE': 0.44265593516835416, 'FOG INDEX': 9.056903806044826, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.909797822706065, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.58104154476302}
# {'File Name': '116.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.447236180455039, 'FOG INDEX': 9.06130377153874, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.905181347150259, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.495032144944478}
# {'File Name': '117.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.05505505499994489, 'SUBJECTIVITY SCORE': 0.4434434429995561, 'FOG INDEX': 9.185974815986375, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.910031023784902, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.543123543123542}
# {'File Name': '118.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.05505505499994489, 'SUBJECTIVITY SCORE': 0.4434434429995561, 'FOG INDEX': 9.185974815986375, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.910031023784902, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.543123543123542}
# {'File Name': '119.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.15800341713449, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.913381742738589, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.625730994152047}
# {'File Name': '120.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.0520520519999479, 'SUBJECTIVITY SCORE': 0.4444444439995551, 'FOG INDEX': 9.06591114376212, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.9062661833247025, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.46760070052539}
# {'File Name': '121.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.052261306480139394, 'SUBJECTIVITY SCORE': 0.44221105483194867, 'FOG INDEX': 9.15779594825482, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.909232365145228, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.567251461988302}
# {'File Name': '122.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44176706782955116, 'FOG INDEX': 9.15800341713449, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.910788381742739, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '123.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44176706782955116, 'FOG INDEX': 9.148679982896587, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.914330218068536, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.63955529549444}
# {'File Name': '124.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44176706782955116, 'FOG INDEX': 9.171988911566698, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.9083376488865875, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '125.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.4437750999560491, 'FOG INDEX': 9.057111167371938, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.910316226023847, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '126.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.055165496434136915, 'SUBJECTIVITY SCORE': 0.44433299855132097, 'FOG INDEX': 9.070725600654823, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.908385093167702, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.525977816695857}
# {'File Name': '127.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.447236180455039, 'FOG INDEX': 9.06130377153874, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.905181347150259, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.495032144944478}
# {'File Name': '128.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05326633160475745, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.148679982896587, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.912772585669782, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.63955529549444}
# {'File Name': '129.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.15800341713449, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.913381742738589, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.625730994152047}
# {'File Name': '130.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.148472298576753, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.913291796469367, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.58104154476302}
# {'File Name': '131.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4448897791133369, 'FOG INDEX': 9.102978039507297, 'WORD COOUNT': 1720, 'AVERAGE WORD PER LENGTH': 4.9020113460546675, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.430232558139537}
# {'File Name': '132.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05315947838198648, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.162457841612541, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.910834629341628, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '133.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.052261306480139394, 'SUBJECTIVITY SCORE': 0.44422110508118484, 'FOG INDEX': 9.143810542398779, 'WORD COOUNT': 1708, 'AVERAGE WORD PER LENGTH': 4.915844155844156, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.594847775175644}
# {'File Name': '134.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.053999999946, 'SUBJECTIVITY SCORE': 0.443999999556, 'FOG INDEX': 9.204829721362229, 'WORD COOUNT': 1717, 'AVERAGE WORD PER LENGTH': 4.9071207430340555, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.587652882935352}
# {'File Name': '135.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.05478087643946128, 'SUBJECTIVITY SCORE': 0.44123505932147905, 'FOG INDEX': 9.018356493395094, 'WORD COOUNT': 1721, 'AVERAGE WORD PER LENGTH': 4.919711785898095, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 407, 'PERCENTAGE OF COMPLEX WORDS': 23.649041255084253}
# {'File Name': '136.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.05310621237163706, 'SUBJECTIVITY SCORE': 0.44589178312034894, 'FOG INDEX': 9.094382346231885, 'WORD COOUNT': 1718, 'AVERAGE WORD PER LENGTH': 4.912751677852349, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 406, 'PERCENTAGE OF COMPLEX WORDS': 23.63213038416764}
# {'File Name': '137.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05310621237163706, 'SUBJECTIVITY SCORE': 0.4418837670923008, 'FOG INDEX': 9.102771747604256, 'WORD COOUNT': 1719, 'AVERAGE WORD PER LENGTH': 4.894275399690562, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.38568935427574}
# {'File Name': '138.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05315947838198648, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.167741542212742, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.9139896373057, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 406, 'PERCENTAGE OF COMPLEX WORDS': 23.714953271028037}
# {'File Name': '139.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.44678714814579606, 'FOG INDEX': 9.15800341713449, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.909751037344399, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.63955529549444}
# {'File Name': '140.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.052261306480139394, 'SUBJECTIVITY SCORE': 0.44221105483194867, 'FOG INDEX': 9.143810542398779, 'WORD COOUNT': 1707, 'AVERAGE WORD PER LENGTH': 4.9111688311688315, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.608670181605156}
# {'File Name': '141.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44176706782955116, 'FOG INDEX': 9.171988911566698, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.9083376488865875, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '142.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.15779594825482, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.909232365145228, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.567251461988302}
# {'File Name': '143.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4408817630852888, 'FOG INDEX': 9.167534288326731, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.9134715025906734, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.642732049036777}
# {'File Name': '145.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05231388324716913, 'SUBJECTIVITY SCORE': 0.44265593516835416, 'FOG INDEX': 9.138940931882109, 'WORD COOUNT': 1707, 'AVERAGE WORD PER LENGTH': 4.911642411642411, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.550087873462214}
# {'File Name': '146.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05231388324716913, 'SUBJECTIVITY SCORE': 0.44265593516835416, 'FOG INDEX': 9.138940931882109, 'WORD COOUNT': 1707, 'AVERAGE WORD PER LENGTH': 4.912681912681912, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.550087873462214}
# {'File Name': '147.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.051307847030877415, 'SUBJECTIVITY SCORE': 0.4436619713846459, 'FOG INDEX': 9.14401833460657, 'WORD COOUNT': 1708, 'AVERAGE WORD PER LENGTH': 4.90961038961039, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.653395784543328}
# {'File Name': '148.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.148679982896587, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.911214953271028, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.63955529549444}
# {'File Name': '149.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44176706782955116, 'FOG INDEX': 9.153549253640222, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.914893617021277, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.684210526315788}
# {'File Name': '150.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05315947838198648, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.162665202939653, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.913426645930534, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.598130841121495}
# {'File Name': '37.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.051153460329836045, 'SUBJECTIVITY SCORE': 0.4463390166034714, 'FOG INDEX': 9.15800341713449, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.911307053941909, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '38.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.06591114376212, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.904712584153288, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.46760070052539}
# {'File Name': '39.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.051153460329836045, 'SUBJECTIVITY SCORE': 0.44433299855132097, 'FOG INDEX': 9.070725600654823, 'WORD COOUNT': 1714, 'AVERAGE WORD PER LENGTH': 4.904244306418219, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.512252042007002}
# {'File Name': '40.txt', 'POSITIVE SCORE': 198, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.050150451303760835, 'SUBJECTIVITY SCORE': 0.4473420256295466, 'FOG INDEX': 9.071139679329772, 'WORD COOUNT': 1714, 'AVERAGE WORD PER LENGTH': 4.904244306418219, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.628938156359393}
# {'File Name': '41.txt', 'POSITIVE SCORE': 199, 'NEGATIVE SCORE': 250, 'POLARITY SCORE': -0.051153460329836045, 'SUBJECTIVITY SCORE': 0.45035105270777226, 'FOG INDEX': 9.06151102542475, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.901036269430052, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '42.txt', 'POSITIVE SCORE': 198, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.050150451303760835, 'SUBJECTIVITY SCORE': 0.4473420256295466, 'FOG INDEX': 9.071139679329772, 'WORD COOUNT': 1714, 'AVERAGE WORD PER LENGTH': 4.904244306418219, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.628938156359393}
# {'File Name': '43.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.051153460329836045, 'SUBJECTIVITY SCORE': 0.44433299855132097, 'FOG INDEX': 9.066325436874497, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.907819782496116, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.584354932866315}
# {'File Name': '45.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.4437750999560491, 'FOG INDEX': 9.057111167371938, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.910316226023847, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '46.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44176706782955116, 'FOG INDEX': 9.056903806044826, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.908761016070502, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.50877192982456}
# {'File Name': '47.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.050200803162448994, 'SUBJECTIVITY SCORE': 0.4437750999560491, 'FOG INDEX': 9.06151102542475, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.905181347150259, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '48.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4448897791133369, 'FOG INDEX': 9.094382346231885, 'WORD COOUNT': 1715, 'AVERAGE WORD PER LENGTH': 4.906040268456376, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.61516034985423}
# {'File Name': '49.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.056903806044826, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.905650596163816, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.553477498538868}
# {'File Name': '50.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.052261306480139394, 'SUBJECTIVITY SCORE': 0.44623115533042096, 'FOG INDEX': 9.052089163369681, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.904045643153527, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.50877192982456}
# {'File Name': '51.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.051153460329836045, 'SUBJECTIVITY SCORE': 0.4463390166034714, 'FOG INDEX': 9.171988911566698, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.904712584153288, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.584354932866315}
# {'File Name': '52.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05315947838198648, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.06171827931076, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.908290155440414, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.598130841121495}
# {'File Name': '53.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.44678714814579606, 'FOG INDEX': 9.06151102542475, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.90259067357513, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '54.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.162665202939653, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.9077242094349405, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.598130841121495}
# {'File Name': '55.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.14401833460657, 'WORD COOUNT': 1708, 'AVERAGE WORD PER LENGTH': 4.9148051948051945, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.653395784543328}
# {'File Name': '56.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4428857710993129, 'FOG INDEX': 9.084754521963825, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.906976744186046, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.543123543123542}
# {'File Name': '58.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.051153460329836045, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.176857873584217, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.912008281573499, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.642732049036777}
# {'File Name': '59.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05310621237163706, 'SUBJECTIVITY SCORE': 0.4438877751063249, 'FOG INDEX': 9.08014718260744, 'WORD COOUNT': 1715, 'AVERAGE WORD PER LENGTH': 4.904343329886246, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.556851311953352}
# {'File Name': '60.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.052999999947, 'SUBJECTIVITY SCORE': 0.442999999557, 'FOG INDEX': 9.09919600643195, 'WORD COOUNT': 1717, 'AVERAGE WORD PER LENGTH': 4.912796697626419, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 407, 'PERCENTAGE OF COMPLEX WORDS': 23.704135119394294}
# {'File Name': '61.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05110220435761302, 'SUBJECTIVITY SCORE': 0.4418837670923008, 'FOG INDEX': 9.066118290318308, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.906784049715173, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.525977816695857}
# {'File Name': '62.txt', 'POSITIVE SCORE': 197, 'NEGATIVE SCORE': 250, 'POLARITY SCORE': -0.05294705289415879, 'SUBJECTIVITY SCORE': 0.4465534461073392, 'FOG INDEX': 9.08035400784012, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.907962771458118, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.6013986013986}
# {'File Name': '63.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.057111167371938, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.903576982892691, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '64.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44578313208254705, 'FOG INDEX': 9.15779594825482, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.906639004149378, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.553477498538868}
# {'File Name': '65.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.057111167371938, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.91187143597719, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '66.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05125628135552133, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.048104657196992, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.910742086144266, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.698069046225864}
# {'File Name': '67.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05326633160475745, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.047897080653142, 'WORD COOUNT': 1708, 'AVERAGE WORD PER LENGTH': 4.912298910223145, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.594847775175644}
# {'File Name': '68.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4428857710993129, 'FOG INDEX': 9.172403204679076, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.920766442257897, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.656542056074766}
# {'File Name': '69.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05110220435761302, 'SUBJECTIVITY SCORE': 0.4418837670923008, 'FOG INDEX': 9.163079925593877, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.921721099015033, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 406, 'PERCENTAGE OF COMPLEX WORDS': 23.714953271028037}
# {'File Name': '70.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44176706782955116, 'FOG INDEX': 9.066325436874497, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.906784049715173, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.584354932866315}
# {'File Name': '71.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.054054053999945895, 'SUBJECTIVITY SCORE': 0.4424424419995571, 'FOG INDEX': 9.075953753052854, 'WORD COOUNT': 1715, 'AVERAGE WORD PER LENGTH': 4.91205380237972, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 406, 'PERCENTAGE OF COMPLEX WORDS': 23.6734693877551}
# {'File Name': '72.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.44678714814579606, 'FOG INDEX': 9.06192553319677, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.909844559585492, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.656542056074766}
# {'File Name': '73.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.4437750999560491, 'FOG INDEX': 9.05229663224935, 'WORD COOUNT': 1710, 'AVERAGE WORD PER LENGTH': 4.906639004149378, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.567251461988302}
# {'File Name': '74.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05305305299994689, 'SUBJECTIVITY SCORE': 0.4414414409995581, 'FOG INDEX': 9.084547803617571, 'WORD COOUNT': 1717, 'AVERAGE WORD PER LENGTH': 4.902842377260982, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.471170646476413}
# {'File Name': '75.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05326633160475745, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.056903806044826, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.905650596163816, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.553477498538868}
# {'File Name': '76.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4428857710993129, 'FOG INDEX': 9.08014718260744, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.904343329886246, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.543123543123542}
# {'File Name': '77.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.051153460329836045, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.162665202939653, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.91187143597719, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.598130841121495}
# {'File Name': '78.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.158210886014158, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.91701244813278, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.670368205727645}
# {'File Name': '79.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.162457841612541, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.908242612752722, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '80.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05220883528894695, 'SUBJECTIVITY SCORE': 0.44578313208254705, 'FOG INDEX': 9.057111167371938, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.911353032659409, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '81.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.0541624874080617, 'SUBJECTIVITY SCORE': 0.44332998952524577, 'FOG INDEX': 9.162872564266765, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.916537065837221, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '82.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05315947838198648, 'SUBJECTIVITY SCORE': 0.4423269804991705, 'FOG INDEX': 9.162665202939653, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.911353032659409, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.598130841121495}
# {'File Name': '83.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.06151102542475, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.906217616580311, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '84.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.0541624874080617, 'SUBJECTIVITY SCORE': 0.44332998952524577, 'FOG INDEX': 9.162872564266765, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.912908242612753, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.656542056074766}
# {'File Name': '85.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05215646935591126, 'SUBJECTIVITY SCORE': 0.4413239714730953, 'FOG INDEX': 9.157588479375153, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.907157676348548, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.495032144944478}
# {'File Name': '86.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05215646935591126, 'SUBJECTIVITY SCORE': 0.4413239714730953, 'FOG INDEX': 9.15779594825482, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.909232365145228, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.553477498538868}
# {'File Name': '87.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05215646935591126, 'SUBJECTIVITY SCORE': 0.4413239714730953, 'FOG INDEX': 9.16732703444072, 'WORD COOUNT': 1711, 'AVERAGE WORD PER LENGTH': 4.9134715025906734, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.611922852133254}
# {'File Name': '88.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.050100200350601004, 'SUBJECTIVITY SCORE': 0.4428857710993129, 'FOG INDEX': 9.070725600654823, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.908902691511387, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.525977816695857}
# {'File Name': '89.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4408817630852888, 'FOG INDEX': 9.071139679329772, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.913043478260869, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.584354932866315}
# {'File Name': '90.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.05383848449268346, 'SUBJECTIVITY SCORE': 0.440677965662335, 'FOG INDEX': 9.099608803129575, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.921052631578948, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 409, 'PERCENTAGE OF COMPLEX WORDS': 23.834498834498834}
# {'File Name': '91.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.052261306480139394, 'SUBJECTIVITY SCORE': 0.44422110508118484, 'FOG INDEX': 9.138940931882109, 'WORD COOUNT': 1707, 'AVERAGE WORD PER LENGTH': 4.911122661122661, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.550087873462214}
# {'File Name': '92.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.052104208364625045, 'SUBJECTIVITY SCORE': 0.4428857710993129, 'FOG INDEX': 9.066532583430684, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.9104091144484725, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.642732049036777}
# {'File Name': '93.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05321285135219593, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.066118290318308, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.908855515277058, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.539719626168225}
# {'File Name': '94.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.0541624874080617, 'SUBJECTIVITY SCORE': 0.44332998952524577, 'FOG INDEX': 9.06192553319677, 'WORD COOUNT': 1712, 'AVERAGE WORD PER LENGTH': 4.910880829015544, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 405, 'PERCENTAGE OF COMPLEX WORDS': 23.656542056074766}
# {'File Name': '95.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 248, 'POLARITY SCORE': -0.054054053999945895, 'SUBJECTIVITY SCORE': 0.4424424419995571, 'FOG INDEX': 9.1669125266687, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.907253886010363, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 402, 'PERCENTAGE OF COMPLEX WORDS': 23.46760070052539}
# {'File Name': '96.txt', 'POSITIVE SCORE': 195, 'NEGATIVE SCORE': 246, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.4427710838928001, 'FOG INDEX': 9.148472298576753, 'WORD COOUNT': 1709, 'AVERAGE WORD PER LENGTH': 4.913291796469367, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.58104154476302}
# {'File Name': '97.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05326633160475745, 'SUBJECTIVITY SCORE': 0.44321607995656676, 'FOG INDEX': 9.148472298576753, 'WORD COOUNT': 1708, 'AVERAGE WORD PER LENGTH': 4.914849428868121, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.594847775175644}
# {'File Name': '98.txt', 'POSITIVE SCORE': 194, 'NEGATIVE SCORE': 249, 'POLARITY SCORE': -0.05505505499994489, 'SUBJECTIVITY SCORE': 0.4434434429995561, 'FOG INDEX': 9.185974815986375, 'WORD COOUNT': 1716, 'AVERAGE WORD PER LENGTH': 4.910031023784902, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 404, 'PERCENTAGE OF COMPLEX WORDS': 23.543123543123542}
# {'File Name': '99.txt', 'POSITIVE SCORE': 196, 'NEGATIVE SCORE': 247, 'POLARITY SCORE': -0.05120481922569797, 'SUBJECTIVITY SCORE': 0.4447791160192981, 'FOG INDEX': 9.171781765010511, 'WORD COOUNT': 1713, 'AVERAGE WORD PER LENGTH': 4.907301916105645, 'SYLLABLE PER WORD': [{'This': 1}, {'is': 1}, {'an': 1}, {'example': 3}, {'sentence': 3}, {'walked': 1}, {'.': 0}], 'COMPLEX WORD COUNT': 403, 'PERCENTAGE OF COMPLEX WORDS': 23.525977816695857}
